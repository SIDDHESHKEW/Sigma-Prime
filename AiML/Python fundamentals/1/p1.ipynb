# %%
print("Ram")
# Out:
# Ram

# %%
#1

name = input("Enter your name")
age = input("enter your age")

print(f"Hello {name}, Your age is {age}.")
# Out:
# Hello , Your age is sf.

# %%
#2

a = int(input("enter a number"))
b = int(input("enter a number"))

sum = a+b
differ = a-b
product = a*b
quotient = a/b


print(sum, differ, product, quotient)
# Out:
# 50 40 225 9.0

# %%
#3

c = float(input("enter a float number"))
print(c)

a = float(a)
b = float(b)

print(a+b+c/3)
# Out:
# 45.0
# 65.0

# %%
#4

d = input("Only enter a number")

integer = int(d)
Float = float(d)
string = str(d)

print(type(integer), type(Float), type(string))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %%
#5

print(10+3*2**2)
# Out:
# 22

# %%
#6 

print(a)
print(b)

a,b = b,a

print(a)
print(b)
# Out:
# 45.0
# 5.0
# 5.0
# 45.0

# %%
#7 

CelsiusTemp = float(input("enter temprature"))
FahrenheitTemp= ((CelsiusTemp*(9/5)) + 32)

print(FahrenheitTemp)
# Out:
# 86.0

# %%
#8

r = int(input("radius"))
Area = 3.14*(r**2)
print(Area)
# Out:
# 314.0

# %%
# 10

Flo = float(input("Enter a float num"))

int_part = int(Flo) 
flo_part = Flo - int(Flo)

print("Input =",Flo)
print("integer part =", int_part)
print("Float part =",flo_part)
# Out:
# Input = 10.1
# integer part = 10
# Float part = 0.09999999999999964

# %%
print(int(Flo))
# Out:
# 10
