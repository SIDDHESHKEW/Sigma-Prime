# %%
print("Ram")
# Out:
# Ram

# %%
#1 

def palindrom_cheaker(word):
    r_word = word[::-1]

    if word == r_word:
        print("An palindrom")
    else:
        print("Not a palindrom")

    print(word)
    print(r_word)


palindrom_cheaker("raar")
# Out:
# An palindrom
# raar
# raar

# %%
word = "hey"
d = word[::-1]
print(d)
# Out:
# yeh
